# %%
# !pip install tensorflow==2.15 tensorflow-model-remediation fairness-indicators==0.46.0 tensorflow-model-analysis==0.46.0 tensorflow-data-validation==1.15.1 --use-deprecated=legacy-resolver
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.15

# %%
import pandas as pd
import tensorflow as tf

import tensorflow_model_analysis as tfma
from google.protobuf import text_format

from tensorflow_model_remediation import min_diff
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_731/983537025.py in <cell line: 0>()
#       2 import tensorflow as tf
#       3
# ----> 4 import tensorflow_model_analysis as tfma
#       5 from google.protobuf import text_format
#       6
#
# ModuleNotFoundError: No module named 'tensorflow_model_analysis'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
